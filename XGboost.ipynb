# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/drive/MyDrive/train_V2.csv')
test =

# %%
df = data

# %%
df = df[df["matchType"]== "duo"]
df
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 2        1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 23       0b6fbdfb59c994  7a75c3e86934f6  8b0a78c005cea0        0       6
# 29       ac5b57ff39979c  857cc55b2b6001  e019e04dee4f19        0       0
# 30       3a4e362d28f411  b4fbf11bf33ac3  cf3d655571b26b        0       0
# 32       e050d1f179d289  9e9fc09bcdab3f  bf3065e01dd3f9        0       3
# ...                 ...             ...             ...      ...     ...
# 1048505  dd0792c2382d3f  1da0e49262bd7e  8c6fcff081e32f        0       0
# 1048522  5912758f70b054  e34e05ecf8f138  c153643b42fa17        0       1
# 1048534  3d7082ddde5489  c43d939cc5bc80  b1b2ce6da85806        0       0
# 1048540  2f3d1cc6e1eaaf  44f4723622b98d  9d4dc128fb6130        0       3
# 1048568  3b1ee9a5a41440  12d27fed986a3a  61e9f5e4cf4394        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 2              68.00      0              0      0         47  ...        0
# 23           1011.00      6              2      2          2  ...        0
# 29              0.00      0              0      0         87  ...        0
# 30             36.73      0              0      0         62  ...        0
# 32              0.00      0              0      1         61  ...        0
# ...              ...    ...            ...    ...        ...  ...      ...
# 1048505       136.60      1              0      0         20  ...        0
# 1048522       157.40      0              1      1         27  ...        0
# 1048534         0.00      0              0      0         64  ...        0
# 1048540        27.31      0              0      0         60  ...        0
# 1048568        22.44      0              0      0         77  ...        0
#
#          rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 2                 0.0          0         0.000          0               0
# 23             4860.0          0         0.000          0               0
# 29                0.0          0         0.000          0               0
# 30                0.0          0         0.000          0               0
# 32             1154.0          0         0.000          1               0
# ...               ...        ...           ...        ...             ...
# 1048505           0.0          0         0.000          0               0
# 1048522         206.4          0         2.497          0               0
# 1048534           0.0          0         0.000          0               0
# 1048540        3541.0          0         0.000          0               0
# 1048568           0.0          0         0.000          0               0
#
#          walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 2               161.8                2          0        0.7755
# 23             2727.0                7       1603        0.9592
# 29                0.0                0          0        0.0000
# 30              455.5                5          0        0.4255
# 32             1240.0                7          0        0.5000
# ...               ...              ...        ...           ...
# 1048505         815.6                3          0        0.4091
# 1048522        2027.0                5          0        0.7021
# 1048534         509.6                2          0        0.3333
# 1048540         819.5                4       1640        0.5000
# 1048568         108.7                2       1500        0.1702
#
# [73511 rows x 29 columns]

# %%
df = df.reset_index()
df
# Out:
#          index              Id         groupId         matchId  assists  \
# 0            2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1
# 1           23  0b6fbdfb59c994  7a75c3e86934f6  8b0a78c005cea0        0
# 2           29  ac5b57ff39979c  857cc55b2b6001  e019e04dee4f19        0
# 3           30  3a4e362d28f411  b4fbf11bf33ac3  cf3d655571b26b        0
# 4           32  e050d1f179d289  9e9fc09bcdab3f  bf3065e01dd3f9        0
# ...        ...             ...             ...             ...      ...
# 73506  1048505  dd0792c2382d3f  1da0e49262bd7e  8c6fcff081e32f        0
# 73507  1048522  5912758f70b054  e34e05ecf8f138  c153643b42fa17        0
# 73508  1048534  3d7082ddde5489  c43d939cc5bc80  b1b2ce6da85806        0
# 73509  1048540  2f3d1cc6e1eaaf  44f4723622b98d  9d4dc128fb6130        0
# 73510  1048568  3b1ee9a5a41440  12d27fed986a3a  61e9f5e4cf4394        0
#
#        boosts  damageDealt  DBNOs  headshotKills  heals  ...  revives  \
# 0           0        68.00      0              0      0  ...        0
# 1           6      1011.00      6              2      2  ...        0
# 2           0         0.00      0              0      0  ...        0
# 3           0        36.73      0              0      0  ...        0
# 4           3         0.00      0              0      1  ...        0
# ...       ...          ...    ...            ...    ...  ...      ...
# 73506       0       136.60      1              0      0  ...        0
# 73507       1       157.40      0              1      1  ...        0
# 73508       0         0.00      0              0      0  ...        0
# 73509       3        27.31      0              0      0  ...        0
# 73510       0        22.44      0              0      0  ...        0
#
#        rideDistance  roadKills  swimDistance  teamKills  vehicleDestroys  \
# 0               0.0          0         0.000          0                0
# 1            4860.0          0         0.000          0                0
# 2               0.0          0         0.000          0                0
# 3               0.0          0         0.000          0                0
# 4            1154.0          0         0.000          1                0
# ...             ...        ...           ...        ...              ...
# 73506           0.0          0         0.000          0                0
# 73507         206.4          0         2.497          0                0
# 73508           0.0          0         0.000          0                0
# 73509        3541.0          0         0.000          0                0
# 73510           0.0          0         0.000          0                0
#
#       walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0            161.8                2          0        0.7755
# 1           2727.0                7       1603        0.9592
# 2              0.0                0          0        0.0000
# 3            455.5                5          0        0.4255
# 4           1240.0                7          0        0.5000
# ...            ...              ...        ...           ...
# 73506        815.6                3          0        0.4091
# 73507       2027.0                5          0        0.7021
# 73508        509.6                2          0        0.3333
# 73509        819.5                4       1640        0.5000
# 73510        108.7                2       1500        0.1702
#
# [73511 rows x 30 columns]

# %%
df.drop(["index"], axis = 1, inplace=True)
df
# Out:
#                    Id         groupId         matchId  assists  boosts  \
# 0      1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 1      0b6fbdfb59c994  7a75c3e86934f6  8b0a78c005cea0        0       6
# 2      ac5b57ff39979c  857cc55b2b6001  e019e04dee4f19        0       0
# 3      3a4e362d28f411  b4fbf11bf33ac3  cf3d655571b26b        0       0
# 4      e050d1f179d289  9e9fc09bcdab3f  bf3065e01dd3f9        0       3
# ...               ...             ...             ...      ...     ...
# 73506  dd0792c2382d3f  1da0e49262bd7e  8c6fcff081e32f        0       0
# 73507  5912758f70b054  e34e05ecf8f138  c153643b42fa17        0       1
# 73508  3d7082ddde5489  c43d939cc5bc80  b1b2ce6da85806        0       0
# 73509  2f3d1cc6e1eaaf  44f4723622b98d  9d4dc128fb6130        0       3
# 73510  3b1ee9a5a41440  12d27fed986a3a  61e9f5e4cf4394        0       0
#
#        damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0            68.00      0              0      0         47  ...        0
# 1          1011.00      6              2      2          2  ...        0
# 2             0.00      0              0      0         87  ...        0
# 3            36.73      0              0      0         62  ...        0
# 4             0.00      0              0      1         61  ...        0
# ...            ...    ...            ...    ...        ...  ...      ...
# 73506       136.60      1              0      0         20  ...        0
# 73507       157.40      0              1      1         27  ...        0
# 73508         0.00      0              0      0         64  ...        0
# 73509        27.31      0              0      0         60  ...        0
# 73510        22.44      0              0      0         77  ...        0
#
#        rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0               0.0          0         0.000          0               0
# 1            4860.0          0         0.000          0               0
# 2               0.0          0         0.000          0               0
# 3               0.0          0         0.000          0               0
# 4            1154.0          0         0.000          1               0
# ...             ...        ...           ...        ...             ...
# 73506           0.0          0         0.000          0               0
# 73507         206.4          0         2.497          0               0
# 73508           0.0          0         0.000          0               0
# 73509        3541.0          0         0.000          0               0
# 73510           0.0          0         0.000          0               0
#
#        walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0             161.8                2          0        0.7755
# 1            2727.0                7       1603        0.9592
# 2               0.0                0          0        0.0000
# 3             455.5                5          0        0.4255
# 4            1240.0                7          0        0.5000
# ...             ...              ...        ...           ...
# 73506         815.6                3          0        0.4091
# 73507        2027.0                5          0        0.7021
# 73508         509.6                2          0        0.3333
# 73509         819.5                4       1640        0.5000
# 73510         108.7                2       1500        0.1702
#
# [73511 rows x 29 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import shapiro, kstest, pearsonr
import numpy as np

# %%
scaler = MinMaxScaler()

# %%
df['weaponsAcquired'] = scaler.fit_transform(df['weaponsAcquired'].to_numpy().reshape(-1, 1))

# %%
df['weaponsAcquired'].plot.hist(bins=30)

# %%
data = data.drop(['matchType'], axis = 1)
data = data.drop(['Id'], axis = 1)
data = data.drop(['groupId'], axis = 1)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 20 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   assists          1048575 non-null  int64
#  1   boosts           1048575 non-null  int64
#  2   damageDealt      1048575 non-null  float64
#  3   DBNOs            1048575 non-null  int64
#  4   headshotKills    1048575 non-null  int64
#  5   heals            1048575 non-null  int64
#  6   killPlace        1048575 non-null  int64
#  7   kills            1048575 non-null  int64
#  8   killStreaks      1048575 non-null  int64
#  9   longestKill      1048575 non-null  float64
#  10  numGroups        1048575 non-null  int64
#  11  revives          1048575 non-null  int64
#  12  rideDistance     1048575 non-null  float64
#  13  roadKills        1048575 non-null  int64
#  14  swimDistance     1048575 non-null  float64
#  15  teamKills        1048575 non-null  int64
#  16  vehicleDestroys  1048575 non-null  int64
#  17  walkDistance     1048575 non-null  float64
#  18  weaponsAcquired  1048575 non-null  int64
#  19  winPlacePerc     1048575 non-null  float64
# dtypes: float64(6), int64(14)
# memory usage: 160.0 MB

# %%
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

X = data.drop(["winPlacePerc"], axis=1)
y = data["winPlacePerc"]

col_names = X.columns

transformer = Normalizer().fit(X)
X = transformer.transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

D_train = xgb.DMatrix(X_train, label=Y_train)
D_test = xgb.DMatrix(X_test, label=Y_test)

# %%
seed = 7
test_size = 0.33

# %%
model = XGBRegressor()
model.fit(X_train, Y_train, eval_metric='mae')
# Out:
# [11:49:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0.77382505, 0.5205887 , 0.8932915 , ..., 0.43671614, 0.7907944 ,
#        0.36631322], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test, y_pred)
print("MAE: {}".format(mae))
# Out:
# MAE: 0.09332107453531381

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from plotnine import *

# %%
fig, ax1 = plt.subplots(figsize=(8,15))
xgb.plot_importance(model, ax=ax1)
plt.show()

# %%
from xgboost import to_graphviz

to_graphviz(model, num_trees=1)

# %%
from sklearn.metrics import mean_squared_error

preds = model.predict(X_test)
best_preds = np.asarray([np.argmax(line) for line in preds])

print("MSE = {}".format(mean_squared_error(Y_test, best_preds)))
# Out:
# MSE = 0.3172679801644612

# %%
comparison_table=pd.DataFrame({'Real':Y_test,'Predict':preds}).sort_index()
comparison_table
# Out:
#            Real   Predict
# 4        0.1875  0.206411
# 7        0.7368  0.567137
# 12       0.9286  0.684103
# 13       0.8750  0.888988
# 17       0.8211  0.843987
# ...         ...       ...
# 1048556  0.2000  0.306351
# 1048559  0.0000  0.046180
# 1048569  0.2500  0.405457
# 1048570  0.4643  0.487679
# 1048572  0.8400  0.820624
#
# [209715 rows x 2 columns]

# %%
import sklearn.metrics as mt

#accuracy = mt.accuracy_score(Y_test, y_pred)
recall = mt.recall_score(Y_test, y_pred)
precision = mt.precision_score(Y_test, y_pred)
f1_score = mt.f1_score(Y_test, y_pred)
matrix = mt.confusion_matrix(Y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-287e972daacc> in <module>()
#       2
#       3 #accuracy = mt.accuracy_score(Y_test, y_pred)
# ----> 4 recall = mt.recall_score(Y_test, y_pred)
#       5 precision = mt.precision_score(Y_test, y_pred)
#       6 f1_score = mt.f1_score(Y_test, y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1907         warn_for=("recall",),
#    1908         sample_weight=sample_weight,
# -> 1909         zero_division=zero_division,
#    1910     )
#    1911     return r
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
#    1543         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1545
#    1546     # Calculate tp_sum, pred_sum, true_sum ###
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#     102     # No metrics support "multiclass-multioutput" format
#     103     if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 104         raise ValueError("{0} is not supported".format(y_type))
#     105
#     106     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ec0d0e3dde08> in <module>()
# ----> 1 print('Accuracy: ', format(accuracy,'.2f'),'\n')
#       2 print('Recall: ', format(recall,'.2f'),'\n')
#       3 print('Precision: ', format(precision,'.2f'),'\n')
#       4 print('F1_score: ', format(f1_score,'.2f'),'\n')
#       5 print('Confusion Matrix:','\n', matrix)
#
# NameError: name 'accuracy' is not defined
